# %%
import pandas as pd
import numpy as np
import fasttext
from tqdm.auto import tqdm
import datetime
# Out:
# 1421187828470398979 2021-07-30 16:15:57 -0300 <spinte8> @crypto_jn @RD_btc @ICOffenderII @gregzaj1  https://t.co/mK2RhJiKbq
# 1421187820564230149 2021-07-30 16:15:55 -0300 <AtaPaykoc> 40K’dan #BTC Longlayınca olanlar
# 1421187816244092930 2021-07-30 16:15:54 -0300 <HFSP13> @BTC_Archive #bitcoin alone is a new world, a magnitude bigger and more powerful than gold. 500K is 10T MC which is the same as gold, so it's the real minimum in a world where 36T bonds give negative interests
# 1421187815371587586 2021-07-30 16:15:54 -0300 <EDSENNA> @BTC_Archive It's gonna take some time. Not now, but i agree. It's inevitable.
# 1421187813303889927 2021-07-30 16:15:53 -0300 <MrDJukis> I actually downloaded BTC wallet and was mining it and it wasn't cash that I earned it was BTC 😅 Oh young me...  Well better now then never.  OG since 2010 😎
# 1421187803111514113 2021-07-30 16:15:51 -0300 <btc_orderalert> 🐋📈【Buy】 BTCUSDT Qty：$1,557,298（39.7 BTC）🐳🐳🐳 Price：$39,200 [19:15:51 UTC] on Binance Futures
# ...

# %%
# Configure
c = twint.Config()
#c.Username = "realDonaldTrump"
c.Search = "btc"

# Run
twint.run.Search(c)
# Out:
# 1421587097807474693 2021-07-31 18:42:30 -0300 <FutureSumer9000> @SalsaTekila Btc is also a vector for spreading contrarian monetary policy
# 1421587093441101826 2021-07-31 18:42:29 -0300 <coincapitan> $BTC Price: $41713 $ETH Price: $2521 $LTC Price: $145  Next update in 10 minutes Last updated: 17:42:27.05
# 1421587089200664583 2021-07-31 18:42:28 -0300 <terstekaldik> #btc Yaprak kıpırdamıyor, bu nedir yav!
# 1421587083282419713 2021-07-31 18:42:27 -0300 <nikhilreddy514> @RuffleyCrypto Solarmoon aims to mine BTC and ETH with the help of solar farms! Helps in reducing the carbon footprint …. Definitely worth checking out! Been 4 weeks since it was launched and already have enough money in the community wallet to acquire the land #SOLARMOON
# 1421587082926034945 2021-07-31 18:42:27 -0300 <BitcoinFNews> Amazon rumored to be accepting Bitcoin, MicoStrategy pledges to buy more BTC despite losses, Bitcoin struggles at $40K: Hodler’s Digest, July 25-31  https://t.co/MCGtq5fczR
# ...
