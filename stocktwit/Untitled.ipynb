# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
data = requests.get('https://stocktwits.com/symbol/BTC.X')

# %%
data
# Out:
# <Response [200]>

# %%
data.text
# Out:
# '<!doctype html>\n<html lang="en"><head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb# profile: http://ogp.me/ns/profile#"><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1.0"/><meta name="apple-mobile-web-app-capable" content="yes"/><title data-rh="true">BTC.X Bitcoin BTC/USD — Stock Price and Discussion | Stocktwits</title><meta data-rh="true" property="og:url" content="https://stocktwits.com/symbol/BTC.X"/><meta data-rh="true" property="og:image" content="https://stocktwits.com/assets/img/stocktwits-logomark-black.png"/><meta data-rh="true" property="og:image:width" content="200"/><meta data-rh="true" property="og:image:height" content="200"/><meta data-rh="true" name="twitter:card" content="summary"/><meta data-rh="true" name="twitter:image" content="https://stocktwits.com/assets/img/stocktwits-logomark-black.png"/><meta data-rh="true" property="og:description" content="Real-time trade and investing ideas on Bitcoin BTC/USD BTC.X fr
# ...
